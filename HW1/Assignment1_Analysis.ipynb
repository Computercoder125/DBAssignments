# %% [markdown]
# <a href="https://colab.research.google.com/github/Computercoder125/DBAssignments/blob/main/HW1/Assignment1_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Sean Gor
# #September 4, 2026
# #Assignment 1 Analysis (saving Google Colab notebooks to Github)

# %% [markdown]
# 1. Based on the instructional videos, what are the key steps for managing files between Google Colab and GitHub?
#
# Answer: According to the video, first, if not done already, you need to create a github account and create a repository, as a foundation. Then, one should link his/her GitHub account to google collab, or use the same google account if signed onto Github via google. one should go to the google colab site, create a new document, and hit the option "save a copy to Github" under the files section. After that, one should choose the repository path to be the repository he/she wants to save the document to. There should be an automatic commit comment "Created Using Colab," and when one is ready, hitting the "ok" button will upload the google collab document into the user's chosen repository/folder according to the file path. You can also select the link in the search bar to ensure the file path in GitHub of the desired repository location is correct.

# %% [markdown]
# 2. Yes, all Module 0 notebooks executed successfully on the first try when I ran all cells. I did not need to make any adjustments to syntax or install additional dependencies — everything ran as expected. It was important that I executed the first one (and all cells in order of when they appear), because sometimes if I miss a previous cell, one or more future cells might throw execution/runtime errors due to undeclared libraries, variables, etc.

# %% [markdown]
# 3. Explain how you created your repository and organized your files (whether using VS Code or the GitHub web interface).
#
# I set up my repository through the GitHub web interface rather than VS Code. I created a new repository called 'Machine Learning,' and within it, created a folder named 'HW1' to hold this assignment's files. From there, I went back to each of the 5 Colab notebooks individually and used the 'Save a copy in GitHub' option to upload them one by one, selecting the Machine Learning repository and specifying the HW1 folder as the file path for each notebook."

# %% [markdown]
# 4. Why is establishing a strong command of basic Python data structures and syntax critical before moving on to core machine learning algorithms?
#
# Establishing a strong command of basic Python data structures and syntax is critical before moving on to core machine learning algorithms because ML work is built entirely on that foundation. Data structures like lists, dictionaries, arrays, and DataFrames are what datasets are stored and manipulated in — cleaning, filtering, reshaping, and merging data all depend on being comfortable with these structures. Additionally, ML libraries like scikit-learn, TensorFlow, and PyTorch expect data to be passed in correctly-shaped arrays or tensors, so if basic indexing, looping, and syntax aren't second nature, even simple tasks like preparing input data or debugging a shape mismatch become far more difficult. Without this foundation, it can become difficult to focus on the actual modeling logic and algorithm behavior, since so much energy gets spent just figuring out the syntax instead of the machine learning concepts themselves.

# %% [markdown]
# ![Image 9-4-26 at 8.26 PM.png](data:image/png;base64,...)

# %% [markdown]
# In the above screenshot, I set up a GitHub Actions CI/CD workflow (.github/workflows/run-notebooks.yml) that automatically executes every notebook in the HW1 folder on a fresh, clean virtual machine (like a laptop) each time changes are pushed to the repository. This verifies that the notebooks run successfully independent of my local Colab environment, rather than relying on packages that happen to already be installed there. It also gave me good experience dealing with running an action on a GitHub respository.
#
# During setup, the workflow initially failed because a notebook imported the seaborn library, which wasn't included in the environment's dependency list — this itself demonstrated why explicit dependency management matters, since Colab has many libraries pre-installed by default that a bare environment does not. After adding seaborn to the workflow's install step, all notebooks executed successfully.
#
# The screenshot shows the successful run, with every step (checkout, environment setup, dependency installation, notebook execution, and artifact upload) completing without errors. The full run can be viewed here: https://github.com/Computercoder125/Machine-Learning/actions/runs/33932337140
